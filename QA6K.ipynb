# %%
import pandas as pd

# %%
data=pd.read_excel("E:\data science\Dataset_w6.xlsx")
data.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia            652864.0
# 1              Albania  SouthernEurope             28748.0
# 2              Algeria  NorthernAfrica           2381741.0
# 3               Angola    MiddleAfrica           1246700.0
# 4  Antigua and Barbuda       Caribbean               442.0
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                         35530.0                         623.2
# 1                          2930.0                        3984.2
# 2                         41318.0                        4154.1
# 3                         29784.0                        4714.1
# 4                           102.0                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                           125.0                                      3568.0
# ...

# %%
data.sort_values("Region")
# Out:
#                     country         Region  Surface area (km2)  \
# 78                    Haiti      Caribbean             27750.0
# 148             Saint Lucia      Caribbean               539.0
# 147   Saint Kitts and Nevis      Caribbean               261.0
# 33           Cayman Islands      Caribbean               264.0
# 24   British Virgin Islands      Caribbean               151.0
# ..                      ...            ...                 ...
# 64                   France  WesternEurope            551500.0
# 8                   Austria  WesternEurope             83871.0
# 69                  Germany  WesternEurope            357376.0
# 169             Switzerland  WesternEurope             41291.0
# 104              Luxembourg  WesternEurope              2586.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 78                          10981.0                         793.7
# 148                           179.0                        7839.4
# ...
